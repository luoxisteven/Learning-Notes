# %%
# 股票市场指数 Ticker 注释
# 道琼斯工业平均指数 (DJIA): ^DJI
# 标准普尔500指数 (S&P 500): ^GSPC
# 纳斯达克综合指数 (NASDAQ Composite): ^IXIC
# 上证综合指数 (SSE Composite Index): 000001.SS
# 恒生指数 (HSI): ^HSI
# 日经225指数 (Nikkei 225): ^N225
# 德国DAX指数: ^GDAXI
# 英国富时100指数 (FTSE 100): ^FTSE
# 法国CAC 40指数: ^FCHI
# 澳洲ASX 200指数: ^AXJO

# ./fin/fin.py
import yfinance as yf

def get_stock_history_data(ticker):
    if not ticker:
        raise ValueError("Ticker parameter is required")
    try:
        dat = yf.Ticker(ticker)
        history_data = dat.history(period='max')
        history_dict = history_data.reset_index().to_dict(orient='records')
        
        return {"ticker": ticker, "history": history_dict}
    except Exception as e:
        raise RuntimeError(f"Error fetching stock data: {e}")
get_stock_history_data("^GSPC")
# Out:
# {'ticker': '^GSPC',
#  'history': [{'Date': Timestamp('1927-12-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.65999984741211,
#    'High': 17.65999984741211,
#    'Low': 17.65999984741211,
#    'Close': 17.65999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-03 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.760000228881836,
#    'High': 17.760000228881836,
#    'Low': 17.760000228881836,
#    'Close': 17.760000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-04 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.719999313354492,
#    'High': 17.719999313354492,
#    'Low': 17.719999313354492,
#    'Close': 17.719999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-05 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.549999237060547,
#    'High': 17.549999237060547,
#    'Low': 17.549999237060547,
#    'Close': 17.549999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-06 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.65999984741211,
#    'High': 17.65999984741211,
#    'Low': 17.65999984741211,
#    'Close': 17.65999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.5,
#    'High': 17.5,
#    'Low': 17.5,
#    'Close': 17.5,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-10 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.3700008392334,
#    'High': 17.3700008392334,
#    'Low': 17.3700008392334,
#    'Close': 17.3700008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-11 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.350000381469727,
#    'High': 17.350000381469727,
#    'Low': 17.350000381469727,
#    'Close': 17.350000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-12 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.469999313354492,
#    'High': 17.469999313354492,
#    'Low': 17.469999313354492,
#    'Close': 17.469999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-13 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.579999923706055,
#    'High': 17.579999923706055,
#    'Low': 17.579999923706055,
#    'Close': 17.579999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.290000915527344,
#    'High': 17.290000915527344,
#    'Low': 17.290000915527344,
#    'Close': 17.290000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-17 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.299999237060547,
#    'High': 17.299999237060547,
#    'Low': 17.299999237060547,
#    'Close': 17.299999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-18 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.260000228881836,
#    'High': 17.260000228881836,
#    'Low': 17.260000228881836,
#    'Close': 17.260000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-19 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.3799991607666,
#    'High': 17.3799991607666,
#    'Low': 17.3799991607666,
#    'Close': 17.3799991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.479999542236328,
#    'High': 17.479999542236328,
#    'Low': 17.479999542236328,
#    'Close': 17.479999542236328,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.639999389648438,
#    'High': 17.639999389648438,
#    'Low': 17.639999389648438,
#    'Close': 17.639999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-24 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.709999084472656,
#    'High': 17.709999084472656,
#    'Low': 17.709999084472656,
#    'Close': 17.709999084472656,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-25 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.520000457763672,
#    'High': 17.520000457763672,
#    'Low': 17.520000457763672,
#    'Close': 17.520000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-26 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.6299991607666,
#    'High': 17.6299991607666,
#    'Low': 17.6299991607666,
#    'Close': 17.6299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.690000534057617,
#    'High': 17.690000534057617,
#    'Low': 17.690000534057617,
#    'Close': 17.690000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.489999771118164,
#    'High': 17.489999771118164,
#    'Low': 17.489999771118164,
#    'Close': 17.489999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-01-31 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.56999969482422,
#    'High': 17.56999969482422,
#    'Low': 17.56999969482422,
#    'Close': 17.56999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-01 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.530000686645508,
#    'High': 17.530000686645508,
#    'Low': 17.530000686645508,
#    'Close': 17.530000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.6299991607666,
#    'High': 17.6299991607666,
#    'Low': 17.6299991607666,
#    'Close': 17.6299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-03 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.399999618530273,
#    'High': 17.399999618530273,
#    'Low': 17.399999618530273,
#    'Close': 17.399999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-06 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.450000762939453,
#    'High': 17.450000762939453,
#    'Low': 17.450000762939453,
#    'Close': 17.450000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-07 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.440000534057617,
#    'High': 17.440000534057617,
#    'Low': 17.440000534057617,
#    'Close': 17.440000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-08 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.489999771118164,
#    'High': 17.489999771118164,
#    'Low': 17.489999771118164,
#    'Close': 17.489999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.549999237060547,
#    'High': 17.549999237060547,
#    'Low': 17.549999237060547,
#    'Close': 17.549999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-10 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.540000915527344,
#    'High': 17.540000915527344,
#    'Low': 17.540000915527344,
#    'Close': 17.540000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-14 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.440000534057617,
#    'High': 17.440000534057617,
#    'Low': 17.440000534057617,
#    'Close': 17.440000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-15 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.399999618530273,
#    'High': 17.399999618530273,
#    'Low': 17.399999618530273,
#    'Close': 17.399999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.350000381469727,
#    'High': 17.350000381469727,
#    'Low': 17.350000381469727,
#    'Close': 17.350000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-17 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.040000915527344,
#    'High': 17.040000915527344,
#    'Low': 17.040000915527344,
#    'Close': 17.040000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 16.950000762939453,
#    'High': 16.950000762939453,
#    'Low': 16.950000762939453,
#    'Close': 16.950000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-21 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.110000610351562,
#    'High': 17.110000610351562,
#    'Low': 17.110000610351562,
#    'Close': 17.110000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.1299991607666,
#    'High': 17.1299991607666,
#    'Low': 17.1299991607666,
#    'Close': 17.1299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-24 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.18000030517578,
#    'High': 17.18000030517578,
#    'Low': 17.18000030517578,
#    'Close': 17.18000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.110000610351562,
#    'High': 17.110000610351562,
#    'Low': 17.110000610351562,
#    'Close': 17.110000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-28 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.15999984741211,
#    'High': 17.15999984741211,
#    'Low': 17.15999984741211,
#    'Close': 17.15999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-02-29 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.260000228881836,
#    'High': 17.260000228881836,
#    'Low': 17.260000228881836,
#    'Close': 17.260000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-01 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.299999237060547,
#    'High': 17.299999237060547,
#    'Low': 17.299999237060547,
#    'Close': 17.299999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.299999237060547,
#    'High': 17.299999237060547,
#    'Low': 17.299999237060547,
#    'Close': 17.299999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-05 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.56999969482422,
#    'High': 17.56999969482422,
#    'Low': 17.56999969482422,
#    'Close': 17.56999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-06 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.670000076293945,
#    'High': 17.670000076293945,
#    'Low': 17.670000076293945,
#    'Close': 17.670000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-07 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.579999923706055,
#    'High': 17.579999923706055,
#    'Low': 17.579999923706055,
#    'Close': 17.579999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-08 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.639999389648438,
#    'High': 17.639999389648438,
#    'Low': 17.639999389648438,
#    'Close': 17.639999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.93000030517578,
#    'High': 17.93000030517578,
#    'Low': 17.93000030517578,
#    'Close': 17.93000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-12 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.0,
#    'High': 18.0,
#    'Low': 18.0,
#    'Close': 18.0,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-13 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.920000076293945,
#    'High': 17.920000076293945,
#    'Low': 17.920000076293945,
#    'Close': 17.920000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-14 00:00:00-0500', tz='America/New_York'),
#    'Open': 17.93000030517578,
#    'High': 17.93000030517578,
#    'Low': 17.93000030517578,
#    'Close': 17.93000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-15 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.06999969482422,
#    'High': 18.06999969482422,
#    'Low': 18.06999969482422,
#    'Close': 18.06999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.260000228881836,
#    'High': 18.260000228881836,
#    'Low': 18.260000228881836,
#    'Close': 18.260000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-19 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.360000610351562,
#    'High': 18.360000610351562,
#    'Low': 18.360000610351562,
#    'Close': 18.360000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.459999084472656,
#    'High': 18.459999084472656,
#    'Low': 18.459999084472656,
#    'Close': 18.459999084472656,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-21 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.649999618530273,
#    'High': 18.649999618530273,
#    'Low': 18.649999618530273,
#    'Close': 18.649999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-22 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.600000381469727,
#    'High': 18.600000381469727,
#    'Low': 18.600000381469727,
#    'Close': 18.600000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.780000686645508,
#    'High': 18.780000686645508,
#    'Low': 18.780000686645508,
#    'Close': 18.780000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-26 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.049999237060547,
#    'High': 19.049999237060547,
#    'Low': 19.049999237060547,
#    'Close': 19.049999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.940000534057617,
#    'High': 18.940000534057617,
#    'Low': 18.940000534057617,
#    'Close': 18.940000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-28 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.889999389648438,
#    'High': 18.889999389648438,
#    'Low': 18.889999389648438,
#    'Close': 18.889999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-29 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.950000762939453,
#    'High': 18.950000762939453,
#    'Low': 18.950000762939453,
#    'Close': 18.950000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-03-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.280000686645508,
#    'High': 19.280000686645508,
#    'Low': 19.280000686645508,
#    'Close': 19.280000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.90999984741211,
#    'High': 18.90999984741211,
#    'Low': 18.90999984741211,
#    'Close': 18.90999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-03 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.020000457763672,
#    'High': 19.020000457763672,
#    'Low': 19.020000457763672,
#    'Close': 19.020000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-04 00:00:00-0500', tz='America/New_York'),
#    'Open': 18.989999771118164,
#    'High': 18.989999771118164,
#    'Low': 18.989999771118164,
#    'Close': 18.989999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-05 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.229999542236328,
#    'High': 19.229999542236328,
#    'Low': 19.229999542236328,
#    'Close': 19.229999542236328,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.270000457763672,
#    'High': 19.270000457763672,
#    'Low': 19.270000457763672,
#    'Close': 19.270000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-10 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.100000381469727,
#    'High': 19.100000381469727,
#    'Low': 19.100000381469727,
#    'Close': 19.100000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-11 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.440000534057617,
#    'High': 19.440000534057617,
#    'Low': 19.440000534057617,
#    'Close': 19.440000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-12 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.40999984741211,
#    'High': 19.40999984741211,
#    'Low': 19.40999984741211,
#    'Close': 19.40999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-13 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.729999542236328,
#    'High': 19.729999542236328,
#    'Low': 19.729999542236328,
#    'Close': 19.729999542236328,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.68000030517578,
#    'High': 19.68000030517578,
#    'Low': 19.68000030517578,
#    'Close': 19.68000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-17 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.520000457763672,
#    'High': 19.520000457763672,
#    'Low': 19.520000457763672,
#    'Close': 19.520000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-18 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.520000457763672,
#    'High': 19.520000457763672,
#    'Low': 19.520000457763672,
#    'Close': 19.520000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-19 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.6299991607666,
#    'High': 19.6299991607666,
#    'Low': 19.6299991607666,
#    'Close': 19.6299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.34000015258789,
#    'High': 19.34000015258789,
#    'Low': 19.34000015258789,
#    'Close': 19.34000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.149999618530273,
#    'High': 19.149999618530273,
#    'Low': 19.149999618530273,
#    'Close': 19.149999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-24 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.25,
#    'High': 19.25,
#    'Low': 19.25,
#    'Close': 19.25,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-25 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.329999923706055,
#    'High': 19.329999923706055,
#    'Low': 19.329999923706055,
#    'Close': 19.329999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-26 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.469999313354492,
#    'High': 19.469999313354492,
#    'Low': 19.469999313354492,
#    'Close': 19.469999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 19.68000030517578,
#    'High': 19.68000030517578,
#    'Low': 19.68000030517578,
#    'Close': 19.68000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-04-30 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.75,
#    'High': 19.75,
#    'Low': 19.75,
#    'Close': 19.75,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-01 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.780000686645508,
#    'High': 19.780000686645508,
#    'Low': 19.780000686645508,
#    'Close': 19.780000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-02 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.829999923706055,
#    'High': 19.829999923706055,
#    'Low': 19.829999923706055,
#    'Close': 19.829999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-03 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.93000030517578,
#    'High': 19.93000030517578,
#    'Low': 19.93000030517578,
#    'Close': 19.93000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-04 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.239999771118164,
#    'High': 20.239999771118164,
#    'Low': 20.239999771118164,
#    'Close': 20.239999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-07 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.40999984741211,
#    'High': 20.40999984741211,
#    'Low': 20.40999984741211,
#    'Close': 20.40999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-08 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.270000457763672,
#    'High': 20.270000457763672,
#    'Low': 20.270000457763672,
#    'Close': 20.270000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-09 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.239999771118164,
#    'High': 20.239999771118164,
#    'Low': 20.239999771118164,
#    'Close': 20.239999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-10 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.209999084472656,
#    'High': 20.209999084472656,
#    'Low': 20.209999084472656,
#    'Close': 20.209999084472656,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-11 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.360000610351562,
#    'High': 20.360000610351562,
#    'Low': 20.360000610351562,
#    'Close': 20.360000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-14 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.440000534057617,
#    'High': 20.440000534057617,
#    'Low': 20.440000534057617,
#    'Close': 20.440000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-15 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.389999389648438,
#    'High': 20.389999389648438,
#    'Low': 20.389999389648438,
#    'Close': 20.389999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-16 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.049999237060547,
#    'High': 20.049999237060547,
#    'Low': 20.049999237060547,
#    'Close': 20.049999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-17 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.1200008392334,
#    'High': 20.1200008392334,
#    'Low': 20.1200008392334,
#    'Close': 20.1200008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-18 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.920000076293945,
#    'High': 19.920000076293945,
#    'Low': 19.920000076293945,
#    'Close': 19.920000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-21 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.6299991607666,
#    'High': 19.6299991607666,
#    'Low': 19.6299991607666,
#    'Close': 19.6299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-22 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.360000610351562,
#    'High': 19.360000610351562,
#    'Low': 19.360000610351562,
#    'Close': 19.360000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-23 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.75,
#    'High': 19.75,
#    'Low': 19.75,
#    'Close': 19.75,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-24 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.8700008392334,
#    'High': 19.8700008392334,
#    'Low': 19.8700008392334,
#    'Close': 19.8700008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-25 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.899999618530273,
#    'High': 19.899999618530273,
#    'Low': 19.899999618530273,
#    'Close': 19.899999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-28 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.56999969482422,
#    'High': 19.56999969482422,
#    'Low': 19.56999969482422,
#    'Close': 19.56999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-29 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.81999969482422,
#    'High': 19.81999969482422,
#    'Low': 19.81999969482422,
#    'Close': 19.81999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-05-31 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.0,
#    'High': 20.0,
#    'Low': 20.0,
#    'Close': 20.0,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-01 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.06999969482422,
#    'High': 20.06999969482422,
#    'Low': 20.06999969482422,
#    'Close': 20.06999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-04 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.799999237060547,
#    'High': 19.799999237060547,
#    'Low': 19.799999237060547,
#    'Close': 19.799999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-05 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.850000381469727,
#    'High': 19.850000381469727,
#    'Low': 19.850000381469727,
#    'Close': 19.850000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-06 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.65999984741211,
#    'High': 19.65999984741211,
#    'Low': 19.65999984741211,
#    'Close': 19.65999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-07 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.610000610351562,
#    'High': 19.610000610351562,
#    'Low': 19.610000610351562,
#    'Close': 19.610000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-08 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.3700008392334,
#    'High': 19.3700008392334,
#    'Low': 19.3700008392334,
#    'Close': 19.3700008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-11 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.68000030517578,
#    'High': 18.68000030517578,
#    'Low': 18.68000030517578,
#    'Close': 18.68000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-12 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.34000015258789,
#    'High': 18.34000015258789,
#    'Low': 18.34000015258789,
#    'Close': 18.34000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-13 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.889999389648438,
#    'High': 18.889999389648438,
#    'Low': 18.889999389648438,
#    'Close': 18.889999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-14 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.049999237060547,
#    'High': 19.049999237060547,
#    'Low': 19.049999237060547,
#    'Close': 19.049999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-15 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.739999771118164,
#    'High': 18.739999771118164,
#    'Low': 18.739999771118164,
#    'Close': 18.739999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-18 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.399999618530273,
#    'High': 18.399999618530273,
#    'Low': 18.399999618530273,
#    'Close': 18.399999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-19 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.34000015258789,
#    'High': 18.34000015258789,
#    'Low': 18.34000015258789,
#    'Close': 18.34000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-20 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.56999969482422,
#    'High': 18.56999969482422,
#    'Low': 18.56999969482422,
#    'Close': 18.56999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-21 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.559999465942383,
#    'High': 18.559999465942383,
#    'Low': 18.559999465942383,
#    'Close': 18.559999465942383,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-22 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.540000915527344,
#    'High': 18.540000915527344,
#    'Low': 18.540000915527344,
#    'Close': 18.540000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-25 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.469999313354492,
#    'High': 18.469999313354492,
#    'Low': 18.469999313354492,
#    'Close': 18.469999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-26 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.68000030517578,
#    'High': 18.68000030517578,
#    'Low': 18.68000030517578,
#    'Close': 18.68000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-27 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.860000610351562,
#    'High': 18.860000610351562,
#    'Low': 18.860000610351562,
#    'Close': 18.860000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-28 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.06999969482422,
#    'High': 19.06999969482422,
#    'Low': 19.06999969482422,
#    'Close': 19.06999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-06-29 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.139999389648438,
#    'High': 19.139999389648438,
#    'Low': 19.139999389648438,
#    'Close': 19.139999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-02 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.979999542236328,
#    'High': 18.979999542236328,
#    'Low': 18.979999542236328,
#    'Close': 18.979999542236328,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-03 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.290000915527344,
#    'High': 19.290000915527344,
#    'Low': 19.290000915527344,
#    'Close': 19.290000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-05 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.479999542236328,
#    'High': 19.479999542236328,
#    'Low': 19.479999542236328,
#    'Close': 19.479999542236328,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-06 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.389999389648438,
#    'High': 19.389999389648438,
#    'Low': 19.389999389648438,
#    'Close': 19.389999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-09 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.459999084472656,
#    'High': 19.459999084472656,
#    'Low': 19.459999084472656,
#    'Close': 19.459999084472656,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-10 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.43000030517578,
#    'High': 19.43000030517578,
#    'Low': 19.43000030517578,
#    'Close': 19.43000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-11 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.950000762939453,
#    'High': 18.950000762939453,
#    'Low': 18.950000762939453,
#    'Close': 18.950000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-12 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.809999465942383,
#    'High': 18.809999465942383,
#    'Low': 18.809999465942383,
#    'Close': 18.809999465942383,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-13 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.959999084472656,
#    'High': 18.959999084472656,
#    'Low': 18.959999084472656,
#    'Close': 18.959999084472656,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-16 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.700000762939453,
#    'High': 18.700000762939453,
#    'Low': 18.700000762939453,
#    'Close': 18.700000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-17 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.799999237060547,
#    'High': 18.799999237060547,
#    'Low': 18.799999237060547,
#    'Close': 18.799999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-18 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.030000686645508,
#    'High': 19.030000686645508,
#    'Low': 19.030000686645508,
#    'Close': 19.030000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-19 00:00:00-0400', tz='America/New_York'),
#    'Open': 18.989999771118164,
#    'High': 18.989999771118164,
#    'Low': 18.989999771118164,
#    'Close': 18.989999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-20 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.030000686645508,
#    'High': 19.030000686645508,
#    'Low': 19.030000686645508,
#    'Close': 19.030000686645508,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-23 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.1200008392334,
#    'High': 19.1200008392334,
#    'Low': 19.1200008392334,
#    'Close': 19.1200008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-24 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.09000015258789,
#    'High': 19.09000015258789,
#    'Low': 19.09000015258789,
#    'Close': 19.09000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-25 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.200000762939453,
#    'High': 19.200000762939453,
#    'Low': 19.200000762939453,
#    'Close': 19.200000762939453,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-26 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.239999771118164,
#    'High': 19.239999771118164,
#    'Low': 19.239999771118164,
#    'Close': 19.239999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-27 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.420000076293945,
#    'High': 19.420000076293945,
#    'Low': 19.420000076293945,
#    'Close': 19.420000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-30 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.469999313354492,
#    'High': 19.469999313354492,
#    'Low': 19.469999313354492,
#    'Close': 19.469999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-07-31 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.43000030517578,
#    'High': 19.43000030517578,
#    'Low': 19.43000030517578,
#    'Close': 19.43000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-01 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.420000076293945,
#    'High': 19.420000076293945,
#    'Low': 19.420000076293945,
#    'Close': 19.420000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-02 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.329999923706055,
#    'High': 19.329999923706055,
#    'Low': 19.329999923706055,
#    'Close': 19.329999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-03 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.360000610351562,
#    'High': 19.360000610351562,
#    'Low': 19.360000610351562,
#    'Close': 19.360000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-06 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.579999923706055,
#    'High': 19.579999923706055,
#    'Low': 19.579999923706055,
#    'Close': 19.579999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-07 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.489999771118164,
#    'High': 19.489999771118164,
#    'Low': 19.489999771118164,
#    'Close': 19.489999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-08 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.25,
#    'High': 19.25,
#    'Low': 19.25,
#    'Close': 19.25,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-09 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.299999237060547,
#    'High': 19.299999237060547,
#    'Low': 19.299999237060547,
#    'Close': 19.299999237060547,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-10 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.25,
#    'High': 19.25,
#    'Low': 19.25,
#    'Close': 19.25,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-13 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.290000915527344,
#    'High': 19.290000915527344,
#    'Low': 19.290000915527344,
#    'Close': 19.290000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-14 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.1299991607666,
#    'High': 19.1299991607666,
#    'Low': 19.1299991607666,
#    'Close': 19.1299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-15 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.469999313354492,
#    'High': 19.469999313354492,
#    'Low': 19.469999313354492,
#    'Close': 19.469999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-16 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.610000610351562,
#    'High': 19.610000610351562,
#    'Low': 19.610000610351562,
#    'Close': 19.610000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-17 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.639999389648438,
#    'High': 19.639999389648438,
#    'Low': 19.639999389648438,
#    'Close': 19.639999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-20 00:00:00-0400', tz='America/New_York'),
#    'Open': 19.770000457763672,
#    'High': 19.770000457763672,
#    'Low': 19.770000457763672,
#    'Close': 19.770000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-21 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.020000457763672,
#    'High': 20.020000457763672,
#    'Low': 20.020000457763672,
#    'Close': 20.020000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-22 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.0,
#    'High': 20.0,
#    'Low': 20.0,
#    'Close': 20.0,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-23 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.020000457763672,
#    'High': 20.020000457763672,
#    'Low': 20.020000457763672,
#    'Close': 20.020000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-24 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.34000015258789,
#    'High': 20.34000015258789,
#    'Low': 20.34000015258789,
#    'Close': 20.34000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-27 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.3799991607666,
#    'High': 20.3799991607666,
#    'Low': 20.3799991607666,
#    'Close': 20.3799991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-28 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.540000915527344,
#    'High': 20.540000915527344,
#    'Low': 20.540000915527344,
#    'Close': 20.540000915527344,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-29 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.579999923706055,
#    'High': 20.579999923706055,
#    'Low': 20.579999923706055,
#    'Close': 20.579999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-30 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.610000610351562,
#    'High': 20.610000610351562,
#    'Low': 20.610000610351562,
#    'Close': 20.610000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-08-31 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.8700008392334,
#    'High': 20.8700008392334,
#    'Low': 20.8700008392334,
#    'Close': 20.8700008392334,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-04 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.969999313354492,
#    'High': 20.969999313354492,
#    'Low': 20.969999313354492,
#    'Close': 20.969999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-05 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.06999969482422,
#    'High': 21.06999969482422,
#    'Low': 21.06999969482422,
#    'Close': 21.06999969482422,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-06 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.940000534057617,
#    'High': 20.940000534057617,
#    'Low': 20.940000534057617,
#    'Close': 20.940000534057617,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-07 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.09000015258789,
#    'High': 21.09000015258789,
#    'Low': 21.09000015258789,
#    'Close': 21.09000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-10 00:00:00-0400', tz='America/New_York'),
#    'Open': 20.920000076293945,
#    'High': 20.920000076293945,
#    'Low': 20.920000076293945,
#    'Close': 20.920000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-11 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.079999923706055,
#    'High': 21.079999923706055,
#    'Low': 21.079999923706055,
#    'Close': 21.079999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-12 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.15999984741211,
#    'High': 21.15999984741211,
#    'Low': 21.15999984741211,
#    'Close': 21.15999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-13 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.139999389648438,
#    'High': 21.139999389648438,
#    'Low': 21.139999389648438,
#    'Close': 21.139999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-14 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.139999389648438,
#    'High': 21.139999389648438,
#    'Low': 21.139999389648438,
#    'Close': 21.139999389648438,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-17 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.329999923706055,
#    'High': 21.329999923706055,
#    'Low': 21.329999923706055,
#    'Close': 21.329999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-18 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.18000030517578,
#    'High': 21.18000030517578,
#    'Low': 21.18000030517578,
#    'Close': 21.18000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-19 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.18000030517578,
#    'High': 21.18000030517578,
#    'Low': 21.18000030517578,
#    'Close': 21.18000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-20 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.219999313354492,
#    'High': 21.219999313354492,
#    'Low': 21.219999313354492,
#    'Close': 21.219999313354492,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-21 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.360000610351562,
#    'High': 21.360000610351562,
#    'Low': 21.360000610351562,
#    'Close': 21.360000610351562,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-24 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.43000030517578,
#    'High': 21.43000030517578,
#    'Low': 21.43000030517578,
#    'Close': 21.43000030517578,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-25 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.40999984741211,
#    'High': 21.40999984741211,
#    'Low': 21.40999984741211,
#    'Close': 21.40999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-26 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.399999618530273,
#    'High': 21.399999618530273,
#    'Low': 21.399999618530273,
#    'Close': 21.399999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1928-09-27 00:00:00-0400', tz='America/New_York'),
#    'Open': 21.1299991607666,
#    'High': 21.1299991607666,
#    'Low': 21.1299991607666,
#    'Close': 21.1299991607666,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
# ...
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-09-25 00:00:00-0400', tz='America/New_York'),
#    'Open': 10.920000076293945,
#    'High': 10.920000076293945,
#    'Low': 10.920000076293945,
#    'Close': 10.920000076293945,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-09-28 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.5,
#    'High': 10.5,
#    'Low': 10.5,
#    'Close': 10.5,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-09-29 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.0600004196167,
#    'High': 10.0600004196167,
#    'Low': 10.0600004196167,
#    'Close': 10.0600004196167,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-09-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.710000038146973,
#    'High': 9.710000038146973,
#    'Low': 9.710000038146973,
#    'Close': 9.710000038146973,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-01 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.529999732971191,
#    'High': 9.529999732971191,
#    'Low': 9.529999732971191,
#    'Close': 9.529999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.699999809265137,
#    'High': 9.699999809265137,
#    'Low': 9.699999809265137,
#    'Close': 9.699999809265137,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-05 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.819999694824219,
#    'High': 8.819999694824219,
#    'Low': 8.819999694824219,
#    'Close': 8.819999694824219,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-06 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.90999984741211,
#    'High': 9.90999984741211,
#    'Low': 9.90999984741211,
#    'Close': 9.90999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-07 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.779999732971191,
#    'High': 9.779999732971191,
#    'Low': 9.779999732971191,
#    'Close': 9.779999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-08 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.619999885559082,
#    'High': 10.619999885559082,
#    'Low': 10.619999885559082,
#    'Close': 10.619999885559082,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.550000190734863,
#    'High': 10.550000190734863,
#    'Low': 10.550000190734863,
#    'Close': 10.550000190734863,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-13 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.100000381469727,
#    'High': 10.100000381469727,
#    'Low': 10.100000381469727,
#    'Close': 10.100000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-14 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.869999885559082,
#    'High': 9.869999885559082,
#    'Low': 9.869999885559082,
#    'Close': 9.869999885559082,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-15 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.050000190734863,
#    'High': 10.050000190734863,
#    'Low': 10.050000190734863,
#    'Close': 10.050000190734863,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.359999656677246,
#    'High': 10.359999656677246,
#    'Low': 10.359999656677246,
#    'Close': 10.359999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-19 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.489999771118164,
#    'High': 10.489999771118164,
#    'Low': 10.489999771118164,
#    'Close': 10.489999771118164,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.960000038146973,
#    'High': 10.960000038146973,
#    'Low': 10.960000038146973,
#    'Close': 10.960000038146973,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-21 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.859999656677246,
#    'High': 10.859999656677246,
#    'Low': 10.859999656677246,
#    'Close': 10.859999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-22 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.5,
#    'High': 10.5,
#    'Low': 10.5,
#    'Close': 10.5,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.84000015258789,
#    'High': 10.84000015258789,
#    'Low': 10.84000015258789,
#    'Close': 10.84000015258789,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-26 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.640000343322754,
#    'High': 10.640000343322754,
#    'Low': 10.640000343322754,
#    'Close': 10.640000343322754,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.40999984741211,
#    'High': 10.40999984741211,
#    'Low': 10.40999984741211,
#    'Close': 10.40999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-28 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.069999694824219,
#    'High': 10.069999694824219,
#    'Low': 10.069999694824219,
#    'Close': 10.069999694824219,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-29 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.109999656677246,
#    'High': 10.109999656677246,
#    'Low': 10.109999656677246,
#    'Close': 10.109999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-10-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.430000305175781,
#    'High': 10.430000305175781,
#    'Low': 10.430000305175781,
#    'Close': 10.430000305175781,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.5,
#    'High': 10.5,
#    'Low': 10.5,
#    'Close': 10.5,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-04 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.819999694824219,
#    'High': 10.819999694824219,
#    'Low': 10.819999694824219,
#    'Close': 10.819999694824219,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-05 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.779999732971191,
#    'High': 10.779999732971191,
#    'Low': 10.779999732971191,
#    'Close': 10.779999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-06 00:00:00-0500', tz='America/New_York'),
#    'Open': 11.109999656677246,
#    'High': 11.109999656677246,
#    'Low': 11.109999656677246,
#    'Close': 11.109999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 11.520000457763672,
#    'High': 11.520000457763672,
#    'Low': 11.520000457763672,
#    'Close': 11.520000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-10 00:00:00-0500', tz='America/New_York'),
#    'Open': 11.279999732971191,
#    'High': 11.279999732971191,
#    'Low': 11.279999732971191,
#    'Close': 11.279999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-11 00:00:00-0500', tz='America/New_York'),
#    'Open': 11.109999656677246,
#    'High': 11.109999656677246,
#    'Low': 11.109999656677246,
#    'Close': 11.109999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-12 00:00:00-0500', tz='America/New_York'),
#    'Open': 11.069999694824219,
#    'High': 11.069999694824219,
#    'Low': 11.069999694824219,
#    'Close': 11.069999694824219,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-13 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.720000267028809,
#    'High': 10.720000267028809,
#    'Low': 10.720000267028809,
#    'Close': 10.720000267028809,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.430000305175781,
#    'High': 10.430000305175781,
#    'Low': 10.430000305175781,
#    'Close': 10.430000305175781,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-17 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.600000381469727,
#    'High': 10.600000381469727,
#    'Low': 10.600000381469727,
#    'Close': 10.600000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-18 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.210000038146973,
#    'High': 10.210000038146973,
#    'Low': 10.210000038146973,
#    'Close': 10.210000038146973,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-19 00:00:00-0500', tz='America/New_York'),
#    'Open': 10.15999984741211,
#    'High': 10.15999984741211,
#    'Low': 10.15999984741211,
#    'Close': 10.15999984741211,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-20 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.850000381469727,
#    'High': 9.850000381469727,
#    'Low': 9.850000381469727,
#    'Close': 9.850000381469727,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.699999809265137,
#    'High': 9.699999809265137,
#    'Low': 9.699999809265137,
#    'Close': 9.699999809265137,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-24 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.869999885559082,
#    'High': 9.869999885559082,
#    'Low': 9.869999885559082,
#    'Close': 9.869999885559082,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-25 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.529999732971191,
#    'High': 9.529999732971191,
#    'Low': 9.529999732971191,
#    'Close': 9.529999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-27 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.3100004196167,
#    'High': 9.3100004196167,
#    'Low': 9.3100004196167,
#    'Close': 9.3100004196167,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-11-30 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.5,
#    'High': 9.5,
#    'Low': 9.5,
#    'Close': 9.5,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-01 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.380000114440918,
#    'High': 9.380000114440918,
#    'Low': 9.380000114440918,
#    'Close': 9.380000114440918,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-02 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.050000190734863,
#    'High': 9.050000190734863,
#    'Low': 9.050000190734863,
#    'Close': 9.050000190734863,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-03 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.220000267028809,
#    'High': 9.220000267028809,
#    'Low': 9.220000267028809,
#    'Close': 9.220000267028809,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-04 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.020000457763672,
#    'High': 9.020000457763672,
#    'Low': 9.020000457763672,
#    'Close': 9.020000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-07 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.289999961853027,
#    'High': 9.289999961853027,
#    'Low': 9.289999961853027,
#    'Close': 9.289999961853027,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-08 00:00:00-0500', tz='America/New_York'),
#    'Open': 9.020000457763672,
#    'High': 9.020000457763672,
#    'Low': 9.020000457763672,
#    'Close': 9.020000457763672,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-09 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.779999732971191,
#    'High': 8.779999732971191,
#    'Low': 8.779999732971191,
#    'Close': 8.779999732971191,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-10 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.579999923706055,
#    'High': 8.579999923706055,
#    'Low': 8.579999923706055,
#    'Close': 8.579999923706055,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-11 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.3100004196167,
#    'High': 8.3100004196167,
#    'Low': 8.3100004196167,
#    'Close': 8.3100004196167,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-14 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.010000228881836,
#    'High': 8.010000228881836,
#    'Low': 8.010000228881836,
#    'Close': 8.010000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-15 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.119999885559082,
#    'High': 8.119999885559082,
#    'Low': 8.119999885559082,
#    'Close': 8.119999885559082,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-16 00:00:00-0500', tz='America/New_York'),
#    'Open': 7.929999828338623,
#    'High': 7.929999828338623,
#    'Low': 7.929999828338623,
#    'Close': 7.929999828338623,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-17 00:00:00-0500', tz='America/New_York'),
#    'Open': 7.71999979019165,
#    'High': 7.71999979019165,
#    'Low': 7.71999979019165,
#    'Close': 7.71999979019165,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-18 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.359999656677246,
#    'High': 8.359999656677246,
#    'Low': 8.359999656677246,
#    'Close': 8.359999656677246,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-21 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.149999618530273,
#    'High': 8.149999618530273,
#    'Low': 8.149999618530273,
#    'Close': 8.149999618530273,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-22 00:00:00-0500', tz='America/New_York'),
#    'Open': 8.289999961853027,
#    'High': 8.289999961853027,
#    'Low': 8.289999961853027,
#    'Close': 8.289999961853027,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-23 00:00:00-0500', tz='America/New_York'),
#    'Open': 7.949999809265137,
#    'High': 7.949999809265137,
#    'Low': 7.949999809265137,
#    'Close': 7.949999809265137,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-24 00:00:00-0500', tz='America/New_York'),
#    'Open': 7.960000038146973,
#    'High': 7.960000038146973,
#    'Low': 7.960000038146973,
#    'Close': 7.960000038146973,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   {'Date': Timestamp('1931-12-28 00:00:00-0500', tz='America/New_York'),
#    'Open': 7.760000228881836,
#    'High': 7.760000228881836,
#    'Low': 7.760000228881836,
#    'Close': 7.760000228881836,
#    'Volume': 0,
#    'Dividends': 0.0,
#    'Stock Splits': 0.0},
#   ...]}

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Fetch historical data for S&P 500
data = get_stock_history_data("^GSPC")
history = pd.DataFrame(data["history"])
history["Date"] = pd.to_datetime(history["Date"])
history.set_index("Date", inplace=True)

# Extract the closing prices
closing_prices = history["Close"]

# Check stationarity (ADF Test)
result = adfuller(closing_prices)
if result[1] > 0.05:
    print("Data is not stationary. Differencing is required.")
    closing_prices = closing_prices.diff().dropna()

# Fit ARIMA model (ARMA is a special case of ARIMA with no differencing)
model = ARIMA(closing_prices, order=(2, 0, 2))  # Adjust order as needed
arma_result = model.fit()

# Forecast future values
forecast_steps = 30
forecast = arma_result.forecast(steps=forecast_steps)

# Plot historical data and forecast
plt.figure(figsize=(12, 6))
plt.plot(closing_prices, label="Historical Data")
plt.plot(pd.date_range(closing_prices.index[-1], periods=forecast_steps, freq="B"), forecast, label="Forecast")
plt.legend()
plt.title("S&P 500 ARIMA Prediction")
plt.show()
# Out:
# Data is not stationary. Differencing is required.
# c:\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
result
# Out:
# (np.float64(5.384678667098815),
#  1.0,
#  47,
#  24401,
#  {'1%': np.float64(-3.430618021312898),
#   '5%': np.float64(-2.861658457177359),
#   '10%': np.float64(-2.566833051314218)},
#  np.float64(199451.508700239))

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.date_range(closing_prices.index[-1], periods=forecast_steps, freq="B"), forecast, label="Forecast")
plt.legend()
plt.title("S&P 500 ARIMA Prediction")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF and PACF
plt.figure(figsize=(12, 6))

# ACF plot
plt.subplot(121)
plot_acf(closing_prices, lags=40, ax=plt.gca())
plt.title("Autocorrelation Function (ACF)")

# PACF plot
plt.subplot(122)
plot_pacf(closing_prices, lags=40, ax=plt.gca(), method='ywm')
plt.title("Partial Autocorrelation Function (PACF)")

plt.tight_layout()
plt.show()
